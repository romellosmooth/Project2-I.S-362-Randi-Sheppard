# %%
import pandas as pd
lottery_df = pd.read_csv(r"C:\Users\Randi\Downloads\Lottery_Powerball_Winning_Numbers__Beginning_2010.csv")

# %%
lottery_df.head()
lottery_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1849 entries, 0 to 1848
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Draw Date        1849 non-null   object
#  1   Winning Numbers  1849 non-null   object
#  2   Multiplier       1639 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 43.5+ KB

# %%
print(lottery_df.shape)
# Out:
# (1849, 3)

# %%
lottery_df = pd.read_csv(r"C:\Users\Randi\Downloads\Lottery_Powerball_Winning_Numbers__Beginning_2010.csv", skiprows=1)

# %%
lottery_df.head(50)
# Out:
#     09/26/2020  11 21 27 36 62 24     3
# 0   09/30/2020  14 18 36 49 67 18   2.0
# 1   10/03/2020  18 31 36 43 47 20   2.0
# 2   10/07/2020  06 24 30 53 56 19   2.0
# 3   10/10/2020  05 18 23 40 50 18   3.0
# 4   10/14/2020  21 37 52 53 58 05   2.0
# 5   10/17/2020  06 10 31 37 44 23   2.0
# 6   10/21/2020  01 03 13 44 56 26   3.0
# 7   10/24/2020  18 20 27 45 65 06   2.0
# 8   10/28/2020  11 28 37 40 53 13   2.0
# 9   10/31/2020  02 06 40 42 55 24   3.0
# 10  11/04/2020  23 32 33 45 49 14   2.0
# 11  11/07/2020  14 16 37 48 58 18   2.0
# 12  11/11/2020  13 15 17 45 63 13   2.0
# 13  11/14/2020  07 15 18 32 45 20   2.0
# 14  11/18/2020  04 05 17 43 52 05   2.0
# 15  11/21/2020  51 54 57 60 69 11   2.0
# 16  11/25/2020  02 57 58 60 65 26   2.0
# 17  11/28/2020  08 12 18 44 51 18   2.0
# 18  12/02/2020  28 31 40 41 46 04   3.0
# 19  12/05/2020  03 04 06 48 53 10   2.0
# 20  12/09/2020  11 14 31 47 48 04   3.0
# 21  12/12/2020  17 54 56 63 69 20   2.0
# ...

# %%
print(lottery_df.columns.tolist())
# Out:
# ['09/26/2020', '11 21 27 36 62 24', '3']

# %%
lottery_df["Draw Date"] = pd.to_datetime(lottery_df["Draw Date"])
lottery_df_sorted = lottery_df.sort_values("Draw Date")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Draw Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ...

# %%
lottery_df.head(20)
# Out:
#     09/26/2020  11 21 27 36 62 24    3
# 0   09/30/2020  14 18 36 49 67 18  2.0
# 1   10/03/2020  18 31 36 43 47 20  2.0
# 2   10/07/2020  06 24 30 53 56 19  2.0
# 3   10/10/2020  05 18 23 40 50 18  3.0
# 4   10/14/2020  21 37 52 53 58 05  2.0
# 5   10/17/2020  06 10 31 37 44 23  2.0
# 6   10/21/2020  01 03 13 44 56 26  3.0
# 7   10/24/2020  18 20 27 45 65 06  2.0
# 8   10/28/2020  11 28 37 40 53 13  2.0
# 9   10/31/2020  02 06 40 42 55 24  3.0
# 10  11/04/2020  23 32 33 45 49 14  2.0
# 11  11/07/2020  14 16 37 48 58 18  2.0
# 12  11/11/2020  13 15 17 45 63 13  2.0
# 13  11/14/2020  07 15 18 32 45 20  2.0
# 14  11/18/2020  04 05 17 43 52 05  2.0
# 15  11/21/2020  51 54 57 60 69 11  2.0
# 16  11/25/2020  02 57 58 60 65 26  2.0
# 17  11/28/2020  08 12 18 44 51 18  2.0
# 18  12/02/2020  28 31 40 41 46 04  3.0
# 19  12/05/2020  03 04 06 48 53 10  2.0

# %%
# Split the string into individual numbers
lottery_df["Winning Numbers"] = lottery_df["Winning Numbers"].astype(str)
lottery_df["Numbers List"] = lottery_df["Winning Numbers"].str.split()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Winning Numbers'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Split the string into individual numbers
# ...

# %%
lottery_df.head(20)
# Out:
#     09/26/2020  11 21 27 36 62 24    3
# 0   09/30/2020  14 18 36 49 67 18  2.0
# 1   10/03/2020  18 31 36 43 47 20  2.0
# 2   10/07/2020  06 24 30 53 56 19  2.0
# 3   10/10/2020  05 18 23 40 50 18  3.0
# 4   10/14/2020  21 37 52 53 58 05  2.0
# 5   10/17/2020  06 10 31 37 44 23  2.0
# 6   10/21/2020  01 03 13 44 56 26  3.0
# 7   10/24/2020  18 20 27 45 65 06  2.0
# 8   10/28/2020  11 28 37 40 53 13  2.0
# 9   10/31/2020  02 06 40 42 55 24  3.0
# 10  11/04/2020  23 32 33 45 49 14  2.0
# 11  11/07/2020  14 16 37 48 58 18  2.0
# 12  11/11/2020  13 15 17 45 63 13  2.0
# 13  11/14/2020  07 15 18 32 45 20  2.0
# 14  11/18/2020  04 05 17 43 52 05  2.0
# 15  11/21/2020  51 54 57 60 69 11  2.0
# 16  11/25/2020  02 57 58 60 65 26  2.0
# 17  11/28/2020  08 12 18 44 51 18  2.0
# 18  12/02/2020  28 31 40 41 46 04  3.0
# 19  12/05/2020  03 04 06 48 53 10  2.0

# %%
print(lottery_df.columns.tolist())
# Out:
# ['09/26/2020', '11 21 27 36 62 24', '3']

# %%
lottery_df["Winning Numbers"] = lottery_df["Winning Numbers"].astype(str)
lottery_df["Numbers List"] = lottery_df["Winning Numbers"].str.split()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Winning Numbers'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ...

# %%
lottery_df.columns = lottery_df.columns.str.strip().str.lower()

# %%
lottery_df["winning numbers"] = lottery_df["winning numbers"].astype(str)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'winning numbers'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ...

# %%
print(lottery_df.columns.tolist())
# Out:
# ['09/26/2020', '11 21 27 36 62 24', '3']

# %%
lottery_df = pd.read_csv(r"C:\Users\Randi\Downloads\Lottery_Powerball_Winning_Numbers__Beginning_2010.csv")

# Clean column names: strip spaces and lowercase
lottery_df.columns = lottery_df.columns.str.strip().str.lower()

# %%
print(lottery_df.columns.tolist())
# Out:
# ['draw date', 'winning numbers', 'multiplier']

# %%
lottery_df["winning numbers"] = lottery_df["winning numbers"].astype(str)
lottery_df["numbers list"] = lottery_df["winning numbers"].str.split()
all_numbers = lottery_df["numbers list"].explode().astype(int)
number_counts = all_numbers.value_counts().sort_values(ascending=False)
number_counts.head(20)
# Out:
# numbers list
# 23    226
# 21    222
# 24    216
# 20    215
# 11    212
# 14    212
# 12    212
# 18    209
# 4     209
# 19    207
# 1     206
# 3     206
# 7     202
# 5     202
# 9     202
# 25    200
# 10    200
# 16    200
# 8     200
# 17    199
# Name: count, dtype: int64
