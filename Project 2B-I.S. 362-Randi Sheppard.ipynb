# %%
import pandas as pd

mta_df = pd.read_csv("mta_art_catalog.csv")
mta_df.head()
## trying to import mta csv file##
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 mta_df = pd.read_csv("mta_art_catalog.csv")
#       4 mta_df.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
mta_df = pd.read_csv(r"C:\Users\Randi\Downloads\mta_art_catalog.csv.csv")
## I tried again to import the csv file and still returned a "No such file or directory##

# %%
import os
print(os.getcwd())
## I used this code to see where the file is located##
# Out:
# C:\Users\Randi

# %%
import pandas as pd

mta_df = pd.read_csv("mta_art_catalog.csv")
mta_df.head()
## this code again returned erros##
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pandas as pd
# ----> 3 mta_df = pd.read_csv("mta_art_catalog.csv")
#       4 mta_df.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
mta_df = pd.read_csv(r"C:\Users\Randi\Downloads\MTA_Permanent_Art_Catalog.csv")
## this didn't work either##
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 mta_df = pd.read_csv(r"C:\Users\Randi\Downloads\MTA_Permanent_Art_Catalog.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
mta_df = pd.read_csv(r"C:\Users\Randi\Downloads\MTA_Permanent_Art_Catalog.1980csv")
## not sure what I am doing wrong but still trying##
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 mta_df = pd.read_csv(r"C:\Users\Randi\Downloads\MTA_Permanent_Art_Catalog.1980csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
mta_dr = pd.read_csv(r"C:\Users\Randi\Downloads\MTA_Permanent_Art_Catalog__Beginning_1980.csv")
##same result with this code##
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 mta_dr = pd.read(r"C:\Users\Randi\Downloads\MTA_Permanent_Art_Catalog__Beginning_1980.csv")
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
import pandas as pd

mta_df = pd.read_csv(r"C:\Users\Randi\Downloads\MTA_Permanent_Art_Catalog__Beginning_1980.csv")
mta_df.head(20)
## this code finally helped me import the mta csv file##
# Out:
#          Agency         Station Name                Line  \
# 0          NYCT             Clark St                 2,3
# 1          NYCT               125 St               4,5,6
# 2          NYCT             Astor Pl                   6
# 3          NYCT            Kings Hwy                 B,Q
# 4          NYCT           Newkirk Av                 B,Q
# 5          NYCT  137 St-City College                   1
# 6          NYCT                23 St                   6
# 7          NYCT                50 St                 C,E
# 8          NYCT                86 St                   1
# 9   Metro-North             Tuckahoe              Harlem
# 10  Metro-North            Fleetwood              Harlem
# 11         NYCT  Grand Central-42 St           S,4,5,6,7
# 12         NYCT              Wall St                 2,3
# 13         NYCT               104 St                 J,Z
# 14         NYCT               111 St                 J,Z
# ...

# %%
mta_df.drop(columns=['Art Image Link'],inplace =True)

# %%
mta_df.head(20)
# Out:
#          Agency         Station Name                Line  \
# 0          NYCT             Clark St                 2,3
# 1          NYCT               125 St               4,5,6
# 2          NYCT             Astor Pl                   6
# 3          NYCT            Kings Hwy                 B,Q
# 4          NYCT           Newkirk Av                 B,Q
# 5          NYCT  137 St-City College                   1
# 6          NYCT                23 St                   6
# 7          NYCT                50 St                 C,E
# 8          NYCT                86 St                   1
# 9   Metro-North             Tuckahoe              Harlem
# 10  Metro-North            Fleetwood              Harlem
# 11         NYCT  Grand Central-42 St           S,4,5,6,7
# 12         NYCT              Wall St                 2,3
# 13         NYCT               104 St                 J,Z
# 14         NYCT               111 St                 J,Z
# ...

# %%
# Sort by artist_name alphabetically
mta_df_sorted = mta_df.sort_values(by='Artist', ascending=True)

# %%
mta_df_sorted.head(20)
## code of ascending
# Out:
#           Agency            Station Name                Line  \
# 130         NYCT    Lexington Av/53rd St               E,M,6
# 101         NYCT       Broadway Junction           A,C,J,L,Z
# 36          LIRR                Bellmore             Babylon
# 35          LIRR                 Merrick             Babylon
# 324         NYCT                   57 St                   F
# 200         NYCT        Wakefield-241 St                   2
# 49          LIRR              Ronkonkoma          Ronkonkoma
# 207         NYCT          St Lawrence Av                   6
# 17   Metro-North           Harlem-125 St  City Terminal Zone
# 286  Metro-North           Harlem-125 St  City Terminal Zone
# 192         LIRR       Atlantic Terminal  City Terminal Zone
# 243         NYCT           Smith-9th Sts                   F
# 254         NYCT           Middletown Rd                   6
# 156         NYCT              Mt Eden Av                   4
# ...
